# %%
st = "chandu ke chacha ne chandu ke chachi ko chandi ke chamche se chutney chatayi"

# %%
words = st.split()
word = words[6]
print(word)
print(word[2])
# Out:
# chachi
# a

# %%
for i in word:
    print(i)
# Out:
# c
# h
# a
# c
# h
# i

# %%
word.index('a')
# Out:
# 2

# %%
for i in range(13, -1, -1):
    print(st.split()[i])
# Out:
# chatayi
# chutney
# se
# chamche
# ke
# chandi
# ko
# chachi
# ke
# chandu
# ne
# chacha
# ke
# chandu

# %%
for i in range(6, -1, -1):
    print(st.split()[i])
# Out:
# chachi
# ke
# chandu
# ne
# chacha
# ke
# chandu

# %%
for i in range(13, 6, -1):
    print(st.split()[i])
# Out:
# chatayi
# chutney
# se
# chamche
# ke
# chandi
# ko
